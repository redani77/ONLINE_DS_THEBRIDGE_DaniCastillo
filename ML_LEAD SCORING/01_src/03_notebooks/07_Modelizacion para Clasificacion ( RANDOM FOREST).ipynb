# %% [markdown]
# # MODELIZACIÓN PARA CLASIFICACIÓN

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pickle
import os

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor

from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

#Desactivar la notación científica
pd.options.display.float_format = '{:.2f}'.format

from sklearn.metrics import roc_curve, auc, roc_auc_score

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
directorio = r"C:\Users\DataScience\ONLINE_DS_THEBRIDGE_DaniCastillo\ML_LEAD SCORING\01_src\01_data_sample\TRABAJO"

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_x = 'x_preseleccionado.pickle'
nombre_y = 'y_preseleccionado.pickle'

# %% [markdown]
# Cargar los datos.

# %%
# Crear la ruta correctamente
ruta_x= os.path.join(directorio, nombre_x)
ruta_y= os.path.join(directorio, nombre_y)


# Cargar el archivo pickle
x = pd.read_pickle(ruta_x)
y = pd.read_pickle(ruta_y)

print("Archivo cargado correctamente.")
# Out:
# Archivo cargado correctamente.

# %%
x
# Out:
#         tiempo_en_site_mms  score_actividad_mms  ult_actividad_SMS Sent  \
# id
# 660737                0.00                 0.70                    0.00
# 660728                0.30                 0.70                    0.00
# 660727                0.68                 0.60                    0.00
# 660719                0.14                 0.50                    0.00
# 660681                0.63                 0.70                    0.00
# ...                    ...                  ...                     ...
# 579622                0.63                 0.60                    1.00
# 579615                0.09                 0.60                    1.00
# 579564                0.82                 0.70                    0.00
# 579546                0.11                 0.60                    1.00
# 579533                0.57                 0.70                    1.00
#
#         visitas_total_mms  paginas_vistas_mms  score_perfil_mms  \
# id
# 660737               0.00                0.00              0.44
# 660728               0.10                0.12              0.44
# 660727               0.04                0.10              1.00
# 660719               0.02                0.05              0.67
# 660681               0.04                0.05              0.78
# ...                   ...                 ...               ...
# 579622               0.26                0.13              0.56
# 579615               0.10                0.12              1.00
# 579564               0.16                0.13              0.67
# 579546               0.04                0.10              0.89
# 579533               0.12                0.15              0.78
#
#         ocupacion_Working Professional  ambito_Select  \
# id
# 660737                            0.00           1.00
# 660728                            0.00           1.00
# 660727                            0.00           0.00
# 660719                            0.00           0.00
# 660681                            0.00           1.00
# ...                                ...            ...
# 579622                            0.00           1.00
# 579615                            0.00           0.00
# 579564                            0.00           0.00
# 579546                            0.00           0.00
# 579533                            0.00           0.00
#
#         ult_actividad_Chat Conversation  ult_actividad_Converted to Lead  \
# id
# 660737                             0.00                             0.00
# 660728                             0.00                             0.00
# 660727                             0.00                             0.00
# 660719                             0.00                             0.00
# 660681                             0.00                             1.00
# ...                                 ...                              ...
# 579622                             0.00                             0.00
# 579615                             0.00                             0.00
# 579564                             0.00                             0.00
# 579546                             0.00                             0.00
# 579533                             0.00                             0.00
#
#         ocupacion_Unemployed  ult_actividad_Page Visited on Website  \
# id
# 660737                  1.00                                   1.00
# 660728                  1.00                                   0.00
# 660727                  0.00                                   0.00
# 660719                  1.00                                   0.00
# 660681                  1.00                                   0.00
# ...                      ...                                    ...
# 579622                  1.00                                   0.00
# 579615                  1.00                                   0.00
# 579564                  1.00                                   0.00
# 579546                  1.00                                   0.00
# 579533                  1.00                                   0.00
#
#         origen_Lead Add Form  fuente_Direct Traffic
# id
# 660737                  0.00                   0.00
# 660728                  0.00                   0.00
# 660727                  0.00                   1.00
# 660719                  0.00                   1.00
# 660681                  0.00                   0.00
# ...                      ...                    ...
# 579622                  0.00                   1.00
# 579615                  0.00                   1.00
# 579564                  0.00                   1.00
# 579546                  0.00                   1.00
# 579533                  0.00                   1.00
#
# [5836 rows x 14 columns]

# %% [markdown]
# ## MODELIZAR

# %% [markdown]
# ### Reservar el dataset de validacion

# %%
train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Crear el pipe y el diccionario de algorimos, parámetros y valores a testar

# %%
pipe = Pipeline([('algoritmo',RandomForestClassifier())])

# %%
grid = [{'algoritmo': [RandomForestRegressor()],
         'algoritmo__n_jobs': [-1],
         'algoritmo__max_depth': [5,10,15],
         'algoritmo__n_estimators': [50,100,200]}
         
        ]

# %% [markdown]
# ### Optimizar los hiper parámetros

# %% [markdown]
# Elegir si se quiere usar grid search o random search.
#
# Comentar la opción que no se vaya a usar.

# %% [markdown]
# ####  Con grid search

# %%
# Configurar GridSearchCV
grid_search = GridSearchCV(
    estimator=pipe,
    param_grid=grid,
    scoring='roc_auc',  
    cv=5,  # Validación cruzada con 5 folds
    verbose=0,
    n_jobs=-1  # Usa todos los núcleos disponibles
)

# %%
 modelo = grid_search.fit(train_x,train_y)

 pd.DataFrame(grid_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
# C:\Users\Viajes Elkano\AppData\Roaming\Python\Python313\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0           0.22          0.02             0.23            0.08
# 1           0.53          0.01             0.01            0.00
# 2           1.15          0.18             0.00            0.00
# 3           0.52          0.13             0.00            0.00
# 4           1.03          0.11             0.00            0.00
# 5           1.79          0.31             0.00            0.00
# 6           1.00          0.15             0.00            0.00
# 7           1.48          0.18             0.00            0.00
# 8           1.96          0.11             0.00            0.00
#
#            param_algoritmo  param_algoritmo__max_depth  \
# 0  RandomForestRegressor()                           5
# 1  RandomForestRegressor()                           5
# 2  RandomForestRegressor()                           5
# 3  RandomForestRegressor()                          10
# 4  RandomForestRegressor()                          10
# 5  RandomForestRegressor()                          10
# 6  RandomForestRegressor()                          15
# 7  RandomForestRegressor()                          15
# 8  RandomForestRegressor()                          15
#
#    param_algoritmo__n_estimators  param_algoritmo__n_jobs  \
# 0                             50                       -1
# 1                            100                       -1
# 2                            200                       -1
# 3                             50                       -1
# 4                            100                       -1
# 5                            200                       -1
# 6                             50                       -1
# 7                            100                       -1
# 8                            200                       -1
#
#                                               params  split0_test_score  \
# 0  {'algoritmo': RandomForestRegressor(), 'algori...                NaN
# 1  {'algoritmo': RandomForestRegressor(), 'algori...                NaN
# 2  {'algoritmo': RandomForestRegressor(), 'algori...                NaN
# 3  {'algoritmo': RandomForestRegressor(), 'algori...                NaN
# 4  {'algoritmo': RandomForestRegressor(), 'algori...                NaN
# 5  {'algoritmo': RandomForestRegressor(), 'algori...                NaN
# 6  {'algoritmo': RandomForestRegressor(), 'algori...                NaN
# 7  {'algoritmo': RandomForestRegressor(), 'algori...                NaN
# 8  {'algoritmo': RandomForestRegressor(), 'algori...                NaN
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
# 5                NaN                NaN                NaN                NaN
# 6                NaN                NaN                NaN                NaN
# 7                NaN                NaN                NaN                NaN
# 8                NaN                NaN                NaN                NaN
#
#    mean_test_score  std_test_score  rank_test_score
# 0              NaN             NaN                1
# 1              NaN             NaN                1
# 2              NaN             NaN                1
# 3              NaN             NaN                1
# 4              NaN             NaN                1
# 5              NaN             NaN                1
# 6              NaN             NaN                1
# 7              NaN             NaN                1
# 8              NaN             NaN                1

# %% [markdown]
# ## EVALUAR

# %% [markdown]
# ### Predecir sobre validación

# %%
pred = modelo.best_estimator_.predict(val_x)

# %% [markdown]
# ### Evaluar sobre validación

# %%
roc_auc_score(val_y, pred)
# Out:
# np.float64(0.8750631155462412)

# %% [markdown]
# ### Examinar el mejor modelo

# %%
modelo.best_estimator_
# Out:
# Pipeline(steps=[('algoritmo',
#                  RandomForestRegressor(max_depth=5, n_estimators=50,
#                                        n_jobs=-1))])

# %% [markdown]
# ## REPORTING DEL MODELO

# %% [markdown]
# ### ROC Chart

# %%
# Obtener predicciones del modelo (valores continuos)
predicciones_continuas = modelo.best_estimator_.predict(val_x)

# Convertir valores continuos a etiquetas binarias usando un umbral (mediana como referencia)
umbral = np.median(predicciones_continuas)
predicciones_binarias = (predicciones_continuas >= umbral).astype(int)

# Calcular métricas ROC
fpr, tpr, _ = roc_curve(val_y, predicciones_continuas)  # Usamos las predicciones continuas
roc_auc = auc(fpr, tpr)

# Crear la gráfica ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'RandomForestRegressor (AUC = {roc_auc:.2f})', linewidth=2)
plt.plot([0, 1], [0, 1], 'k--', label='Referencia (AUC = 0.50)')  # Línea de referencia

# Configurar etiquetas y título
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC - RandomForestRegressor')
plt.legend(loc='lower right')
plt.grid()

# Mostrar la gráfica
plt.show()

# Imprimir el AUC
print(f'ROC AUC Score: {roc_auc:.4f}')
# Out:
# ROC AUC Score: 0.8751

# %%
ruta_modelo = r"C:\Users\DataScience\ONLINE_DS_THEBRIDGE_DaniCastillo\ML_LEAD SCORING\01_src\06_models.modelo_random_forest_regresor.pkl"

with open(ruta_modelo, 'wb') as archivo:
    pickle.dump(modelo.best_estimator_, archivo)

print(f"Modelo guardado en: {ruta_modelo}")
# Out:
# Modelo guardado en: C:\Users\DataScience\ONLINE_DS_THEBRIDGE_DaniCastillo\ML_LEAD SCORING\01_src\06_models.modelo_random_forest_regresor.pkl
