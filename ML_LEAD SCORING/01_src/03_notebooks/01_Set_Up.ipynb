# %% [markdown]
# ## CREAR EL ENTORNO PARA EL PROYECTO

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import os
import pandas as pd
import numpy as np
import os
from janitor import clean_names

# %% [markdown]
# ## CREAR EL DIRECTORIO DEL PROYECTO

# %% [markdown]
# ### Definir el directorio raiz donde vamos a crear el proyecto

# %%
directorio = "C:/Users/DataScience/ONLINE_DS_THEBRIDGE_DaniCastillo"

# %% [markdown]
# ### Definir el nombre del proyecto

# %%
nombre_dir ="ML_LEAD SCORING"

# %% [markdown]
# ### Crear el directorio y la estructura del proyecto

# %%
path = os.path.join(directorio, nombre_dir)

try:

    os.mkdir(path)
    os.mkdir(path + '/01_src')
    os.mkdir(path + '/01_src/01_data_sample')
    os.mkdir(path + '/01_src//02_img')
    os.mkdir(path + '/01_src/03_notebooks')
    os.mkdir(path + '/01_src/04_results_notebook')
    os.mkdir(path + '/01_src/06_models')
    os.mkdir(path + '/01_src/07_utils')
      
except OSError:
    print ("La creación del directorio %s ha fallado" % path)
else:
    print ("Se ha creado satisfactoriamente el directorio %s " % path)
# Out:
# La creación del directorio C:/Users/DataScience/ONLINE_DS_THEBRIDGE_DaniCastillo\ML_LEAD SCORING ha fallado

# %% [markdown]
# ### Situar el directorio de trabajo en el proyecto

# %%
os.chdir(path)

# %% [markdown]
# ## CREAR LOS DATASETS INICIALES

# %% [markdown]
# ### Importar los datos

# %%
nombre_fichero_datos = 'Leads.csv'

# %% [markdown]
# Cargar los datos.

# %%
ruta = path + '/01_src/01_data_sample/' + nombre_fichero_datos

df = pd.read_csv(ruta, sep=";",index_col=0,)
df
# Out:
#                          origen          fuente no_enviar_email no_llamar  \
# id
# 660737                      API            Chat              No        No
# 660728                      API  Organic Search              No        No
# 660727  Landing Page Submission  Direct Traffic              No        No
# 660719  Landing Page Submission  Direct Traffic              No        No
# 660681  Landing Page Submission          Google              No        No
# ...                         ...             ...             ...       ...
# 579564  Landing Page Submission  Direct Traffic             Yes        No
# 579546  Landing Page Submission  Direct Traffic              No        No
# 579545  Landing Page Submission  Direct Traffic             Yes        No
# 579538  Landing Page Submission          Google              No        No
# 579533  Landing Page Submission  Direct Traffic              No        No
#
# ...

# %% [markdown]
# ### Extraer y reservar el dataset de validación

# %%
val= df.sample(frac = 0.2)

# %%
nombre_fichero_validacion = 'validacion.csv'

ruta_completa = path + '/01_src/01_data_sample/' + nombre_fichero_validacion

val.to_csv(ruta_completa)

# %%
val
# Out:
#                          origen          fuente no_enviar_email no_llamar  \
# id
# 604622                      API            Chat              No        No
# 579545  Landing Page Submission  Direct Traffic             Yes        No
# 654842  Landing Page Submission  Direct Traffic              No        No
# 591695                      API          Google              No        No
# 645342  Landing Page Submission  Direct Traffic              No        No
# ...                         ...             ...             ...       ...
# 589518  Landing Page Submission  Direct Traffic              No        No
# 583075                      API            Chat              No        No
# 611560                      API  Organic Search              No        No
# 580808  Landing Page Submission  Direct Traffic              No        No
# 595176  Landing Page Submission          Google              No        No
#
# ...

# %% [markdown]
# ### Extraer y guardar el dataset de trabajo

# %%
trabajo = df.loc[~df.index.isin(val.index)]

# %%
nombre_fichero_trabajo = 'trabajo.csv'

ruta_completa = path + '/01_src/01_data_sample/' + nombre_fichero_trabajo

trabajo.to_csv(ruta_completa)

# %%
trabajo
# Out:
#                          origen          fuente no_enviar_email no_llamar  \
# id
# 660737                      API            Chat              No        No
# 660728                      API  Organic Search              No        No
# 660727  Landing Page Submission  Direct Traffic              No        No
# 660719  Landing Page Submission  Direct Traffic              No        No
# 660681  Landing Page Submission          Google              No        No
# ...                         ...             ...             ...       ...
# 579622                      API  Direct Traffic              No        No
# 579615  Landing Page Submission  Direct Traffic              No        No
# 579564  Landing Page Submission  Direct Traffic             Yes        No
# 579546  Landing Page Submission  Direct Traffic              No        No
# 579533  Landing Page Submission  Direct Traffic              No        No
#
# ...
