# %% [markdown]
# ## Kaggle – DataTops®
# Luismi ha decidido cambiar de aires y, por eso, ha comprado una tienda de portátiles. Sin embargo, su única especialidad es Data Science, por lo que ha decidido crear un modelo de ML para establecer los mejores precios.
#
# ¿Podrías ayudar a Luismi a mejorar ese modelo?

# %% [markdown]
# ## Métrica:
# Error de raíz cuadrada media (RMSE) es la desviación estándar de los valores residuales (errores de predicción). Los valores residuales son una medida de la distancia de los puntos de datos de la línea de regresión; RMSE es una medida de cuál es el nivel de dispersión de estos valores residuales. En otras palabras, le indica el nivel de concentración de los datos en la línea de mejor ajuste.
#
#
# $$ RMSE = \sqrt{\frac{1}{n}\Sigma_{i=1}^{n}{\Big(\frac{d_i -f_i}{\sigma_i}\Big)^2}}$$

# %% [markdown]
# ## Librerías

# %%
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split,cross_val_score, KFold
from sklearn.metrics import mean_squared_error, root_mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
import urllib.request
import matplotlib.pyplot as plt

# %% [markdown]
# ## Datos

# %%
# Para que funcione necesitas bajarte los archivos de datos de Kaggle 
df = pd.read_csv("./data/train.csv", index_col = ["laptop_ID"])
df
# Out:
#           Company             Product            TypeName  Inches  \
# laptop_ID
# 755            HP              250 G6            Notebook    15.6
# 618          Dell       Inspiron 7559              Gaming    15.6
# 909            HP         ProBook 450            Notebook    15.6
# 2           Apple         Macbook Air           Ultrabook    13.3
# 286          Dell       Inspiron 3567            Notebook    15.6
# ...           ...                 ...                 ...     ...
# 28           Dell       Inspiron 5570            Notebook    15.6
# 1160           HP         Spectre Pro  2 in 1 Convertible    13.3
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 23             HP              255 G6            Notebook    15.6
# 229          Dell        Alienware 17              Gaming    17.3
#
#                           ScreenResolution                           Cpu  \
# laptop_ID
# 755                      Full HD 1920x1080      Intel Core i3 6006U 2GHz
# 618                      Full HD 1920x1080   Intel Core i7 6700HQ 2.6GHz
# 909                      Full HD 1920x1080    Intel Core i7 7500U 2.7GHz
# 2                                 1440x900          Intel Core i5 1.8GHz
# 286                      Full HD 1920x1080    Intel Core i3 6006U 2.0GHz
# ...                                    ...                           ...
# 28                       Full HD 1920x1080    Intel Core i5 8250U 1.6GHz
# 1160       Full HD / Touchscreen 1920x1080    Intel Core i5 6300U 2.4GHz
# 78                       Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# 23                                1366x768  AMD E-Series E2-9000e 1.5GHz
# 229            IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
#
#             Ram                Memory                             Gpu  \
# laptop_ID
# 755         8GB             256GB SSD           Intel HD Graphics 520
# 618        16GB               1TB HDD  Nvidia GeForce GTX 960<U+039C>
# 909         8GB               1TB HDD            Nvidia GeForce 930MX
# 2           8GB   128GB Flash Storage          Intel HD Graphics 6000
# 286         4GB               1TB HDD              AMD Radeon R5 M430
# ...         ...                   ...                             ...
# 28          8GB             256GB SSD                  AMD Radeon 530
# 1160        8GB             256GB SSD           Intel HD Graphics 520
# 78          8GB               2TB HDD           Intel HD Graphics 620
# 23          4GB             500GB HDD                   AMD Radeon R2
# 229        16GB  256GB SSD +  1TB HDD         Nvidia GeForce GTX 1060
#
#                 OpSys  Weight  Price_in_euros
# laptop_ID
# 755        Windows 10  1.86kg          539.00
# 618        Windows 10  2.59kg          879.01
# 909        Windows 10  2.04kg          900.00
# 2               macOS  1.34kg          898.94
# 286             Linux  2.25kg          428.00
# ...               ...     ...             ...
# 28         Windows 10   2.2kg          800.00
# 1160       Windows 10  1.48kg         1629.00
# 78              No OS   2.2kg          519.00
# 23              No OS  1.86kg          258.00
# 229        Windows 10  4.42kg         2456.34
#
# [912 rows x 12 columns]

# %% [markdown]
# ## Exploración de los datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches            912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   Ram               912 non-null    object
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight            912 non-null    object
#  11  Price_in_euros    912 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 92.6+ KB

# %%
df.head()
# Out:
#           Company        Product   TypeName  Inches   ScreenResolution  \
# laptop_ID
# 755            HP         250 G6   Notebook    15.6  Full HD 1920x1080
# 618          Dell  Inspiron 7559     Gaming    15.6  Full HD 1920x1080
# 909            HP    ProBook 450   Notebook    15.6  Full HD 1920x1080
# 2           Apple    Macbook Air  Ultrabook    13.3           1440x900
# 286          Dell  Inspiron 3567   Notebook    15.6  Full HD 1920x1080
#
#                                    Cpu   Ram               Memory  \
# laptop_ID
# 755           Intel Core i3 6006U 2GHz   8GB            256GB SSD
# 618        Intel Core i7 6700HQ 2.6GHz  16GB              1TB HDD
# 909         Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
# 2                 Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 286         Intel Core i3 6006U 2.0GHz   4GB              1TB HDD
#
#                                       Gpu       OpSys  Weight  Price_in_euros
# laptop_ID
# 755                 Intel HD Graphics 520  Windows 10    1.86          539.00
# 618        Nvidia GeForce GTX 960<U+039C>  Windows 10    2.59          879.01
# 909                  Nvidia GeForce 930MX  Windows 10    2.04          900.00
# 2                  Intel HD Graphics 6000       macOS    1.34          898.94
# 286                    AMD Radeon R5 M430       Linux    2.25          428.00

# %%
df.tail()
# Out:
#           Company             Product            TypeName  Inches  \
# laptop_ID
# 28           Dell       Inspiron 5570            Notebook    15.6
# 1160           HP         Spectre Pro  2 in 1 Convertible    13.3
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 23             HP              255 G6            Notebook    15.6
# 229          Dell        Alienware 17              Gaming    17.3
#
#                           ScreenResolution                           Cpu  \
# laptop_ID
# 28                       Full HD 1920x1080    Intel Core i5 8250U 1.6GHz
# 1160       Full HD / Touchscreen 1920x1080    Intel Core i5 6300U 2.4GHz
# 78                       Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# 23                                1366x768  AMD E-Series E2-9000e 1.5GHz
# 229            IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
#
#             Ram                Memory                      Gpu       OpSys  \
# laptop_ID
# 28          8GB             256GB SSD           AMD Radeon 530  Windows 10
# 1160        8GB             256GB SSD    Intel HD Graphics 520  Windows 10
# 78          8GB               2TB HDD    Intel HD Graphics 620       No OS
# 23          4GB             500GB HDD            AMD Radeon R2       No OS
# 229        16GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10
#
#            Weight  Price_in_euros
# laptop_ID
# 28           2.20          800.00
# 1160         1.48         1629.00
# 78           2.20          519.00
# 23           1.86          258.00
# 229          4.42         2456.34

# %%
df["Ram"]= df["Ram"].str.replace("GB", "").astype(float)
df
# Out:
#           Company             Product            TypeName  Inches  \
# laptop_ID
# 755            HP              250 G6            Notebook    15.6
# 618          Dell       Inspiron 7559              Gaming    15.6
# 909            HP         ProBook 450            Notebook    15.6
# 2           Apple         Macbook Air           Ultrabook    13.3
# 286          Dell       Inspiron 3567            Notebook    15.6
# ...           ...                 ...                 ...     ...
# 28           Dell       Inspiron 5570            Notebook    15.6
# 1160           HP         Spectre Pro  2 in 1 Convertible    13.3
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 23             HP              255 G6            Notebook    15.6
# 229          Dell        Alienware 17              Gaming    17.3
#
#                           ScreenResolution                           Cpu  \
# laptop_ID
# 755                      Full HD 1920x1080      Intel Core i3 6006U 2GHz
# 618                      Full HD 1920x1080   Intel Core i7 6700HQ 2.6GHz
# 909                      Full HD 1920x1080    Intel Core i7 7500U 2.7GHz
# 2                                 1440x900          Intel Core i5 1.8GHz
# 286                      Full HD 1920x1080    Intel Core i3 6006U 2.0GHz
# ...                                    ...                           ...
# 28                       Full HD 1920x1080    Intel Core i5 8250U 1.6GHz
# 1160       Full HD / Touchscreen 1920x1080    Intel Core i5 6300U 2.4GHz
# 78                       Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# 23                                1366x768  AMD E-Series E2-9000e 1.5GHz
# 229            IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
#
#             Ram                Memory                             Gpu  \
# laptop_ID
# 755         8.0             256GB SSD           Intel HD Graphics 520
# 618        16.0               1TB HDD  Nvidia GeForce GTX 960<U+039C>
# 909         8.0               1TB HDD            Nvidia GeForce 930MX
# 2           8.0   128GB Flash Storage          Intel HD Graphics 6000
# 286         4.0               1TB HDD              AMD Radeon R5 M430
# ...         ...                   ...                             ...
# 28          8.0             256GB SSD                  AMD Radeon 530
# 1160        8.0             256GB SSD           Intel HD Graphics 520
# 78          8.0               2TB HDD           Intel HD Graphics 620
# 23          4.0             500GB HDD                   AMD Radeon R2
# 229        16.0  256GB SSD +  1TB HDD         Nvidia GeForce GTX 1060
#
#                 OpSys  Weight  Price_in_euros
# laptop_ID
# 755        Windows 10  1.86kg          539.00
# 618        Windows 10  2.59kg          879.01
# 909        Windows 10  2.04kg          900.00
# 2               macOS  1.34kg          898.94
# 286             Linux  2.25kg          428.00
# ...               ...     ...             ...
# 28         Windows 10   2.2kg          800.00
# 1160       Windows 10  1.48kg         1629.00
# 78              No OS   2.2kg          519.00
# 23              No OS  1.86kg          258.00
# 229        Windows 10  4.42kg         2456.34
#
# [912 rows x 12 columns]

# %%
df["Weight"]= df["Weight"].str.replace("kg", "").astype(float)
df
# Out:
#           Company             Product            TypeName  Inches  \
# laptop_ID
# 755            HP              250 G6            Notebook    15.6
# 618          Dell       Inspiron 7559              Gaming    15.6
# 909            HP         ProBook 450            Notebook    15.6
# 2           Apple         Macbook Air           Ultrabook    13.3
# 286          Dell       Inspiron 3567            Notebook    15.6
# ...           ...                 ...                 ...     ...
# 28           Dell       Inspiron 5570            Notebook    15.6
# 1160           HP         Spectre Pro  2 in 1 Convertible    13.3
# 78         Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 23             HP              255 G6            Notebook    15.6
# 229          Dell        Alienware 17              Gaming    17.3
#
#                           ScreenResolution                           Cpu  \
# laptop_ID
# 755                      Full HD 1920x1080      Intel Core i3 6006U 2GHz
# 618                      Full HD 1920x1080   Intel Core i7 6700HQ 2.6GHz
# 909                      Full HD 1920x1080    Intel Core i7 7500U 2.7GHz
# 2                                 1440x900          Intel Core i5 1.8GHz
# 286                      Full HD 1920x1080    Intel Core i3 6006U 2.0GHz
# ...                                    ...                           ...
# 28                       Full HD 1920x1080    Intel Core i5 8250U 1.6GHz
# 1160       Full HD / Touchscreen 1920x1080    Intel Core i5 6300U 2.4GHz
# 78                       Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# 23                                1366x768  AMD E-Series E2-9000e 1.5GHz
# 229            IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
#
#             Ram                Memory                             Gpu  \
# laptop_ID
# 755         8.0             256GB SSD           Intel HD Graphics 520
# 618        16.0               1TB HDD  Nvidia GeForce GTX 960<U+039C>
# 909         8.0               1TB HDD            Nvidia GeForce 930MX
# 2           8.0   128GB Flash Storage          Intel HD Graphics 6000
# 286         4.0               1TB HDD              AMD Radeon R5 M430
# ...         ...                   ...                             ...
# 28          8.0             256GB SSD                  AMD Radeon 530
# 1160        8.0             256GB SSD           Intel HD Graphics 520
# 78          8.0               2TB HDD           Intel HD Graphics 620
# 23          4.0             500GB HDD                   AMD Radeon R2
# 229        16.0  256GB SSD +  1TB HDD         Nvidia GeForce GTX 1060
#
#                 OpSys  Weight  Price_in_euros
# laptop_ID
# 755        Windows 10    1.86          539.00
# 618        Windows 10    2.59          879.01
# 909        Windows 10    2.04          900.00
# 2               macOS    1.34          898.94
# 286             Linux    2.25          428.00
# ...               ...     ...             ...
# 28         Windows 10    2.20          800.00
# 1160       Windows 10    1.48         1629.00
# 78              No OS    2.20          519.00
# 23              No OS    1.86          258.00
# 229        Windows 10    4.42         2456.34
#
# [912 rows x 12 columns]

# %%
df.describe().T
# Out:
#                 count         mean         std     min     25%     50%  \
# Inches          912.0    14.981579    1.436719   10.10   14.00   15.60
# Ram             912.0     8.263158    5.044788    2.00    4.00    8.00
# Weight          912.0     2.026937    0.665466    0.69    1.49    2.04
# Price_in_euros  912.0  1111.724090  687.959172  174.00  589.00  978.00
#
#                       75%     max
# Inches            15.6000    18.4
# Ram                8.0000    64.0
# Weight             2.3000     4.7
# Price_in_euros  1483.9425  6099.0

# %% [markdown]
# ## Procesado de datos

# %% [markdown]
# Nuestro target es la columna `Price_in_euros`

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Modelado

# %% [markdown]
# ### 1. Definir X e y

# %%
features = [
    "Inches",
    "Weight",
    "Ram"
]

target = [
    "Price_in_euros"
]

# %%
# X = df.drop(['Price_in_euros'], axis=1)
X = df[features].copy()
y = df['Price_in_euros'].copy()
X.shape
# Out:
# (912, 3)

# %%
y.shape
# Out:
# (912,)

# %% [markdown]
# ### 2. Dividir X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# ### 3. Baseline de modelos

# %%
# 4. Crear modelo Random Forest
model = RandomForestRegressor(
    n_estimators=100,  # Número de árboles en el bosque
    random_state=42,   # Semilla para reproducibilidad
    n_jobs=-1          # Usar todos los núcleos del procesador
)

# %%
# 5. Validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(model, X_train, y_train, cv=kfold, scoring='neg_mean_squared_error')

# %%
# Convertir a MSE positivo y calcular media y desviación estándar
mse_scores = -cv_scores
print(f"MSE Validación Cruzada: {mse_scores.mean():.2f} (± {mse_scores.std():.2f})")
# Out:
# MSE Validación Cruzada: 167038.66 (± 32272.01)

# %%
# 6. Entrenar modelo con todos los datos de entrenamiento
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %% [markdown]
# ### 4. Sacar métricas, valorar los modelos
#
# Recuerda que en la competición se va a evaluar con la métrica de ``RMSE``.

# %%
# 7. Evaluar en conjunto de prueba
y_pred = model.predict(X_test)
print(f"\nMSE Test: {mean_squared_error(y_test, y_pred):.2f}")
print(f"R² Test: {r2_score(y_test, y_pred):.2f}")
# Out:
# MSE Test: 227371.10
# R² Test: 0.59

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# 476.8344583373976

# %%
# 8. Importancia de las features
feature_importance = pd.Series(model.feature_importances_, index=X.columns)
print("\nImportancia de las features:")
print(feature_importance.sort_values(ascending=False))
# Out:
# Importancia de las features:
# Ram       0.649832
# Weight    0.301273
# Inches    0.048895
# dtype: float64

# %%
# (Opcional) Visualización de importancia de features
feature_importance.sort_values().plot(kind='barh')
plt.title('Importancia de las Features')
plt.show()

# %%
# (Opcional) Gráfico de predicciones vs valores reales
plt.scatter(y_test, y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Valores Reales')
plt.ylabel('Predicciones')
plt.title('Predicciones vs Valores Reales')
plt.show()

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir ``test.csv``

# %% [markdown]
# **RECUERDA: APLICAR LAS TRANSFORMACIONES QUE HAYAS REALIZADO EN `train.csv` a `test.csv`.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ### 1. Carga los datos de `test.csv` para predecir.

# %%
X_pred = pd.read_csv("./data/test.csv", index_col = ["laptop_ID"])
X_pred.index.name = None
X_pred.head()
# Out:
#      Company                          Product            TypeName  Inches  \
# 209   Lenovo               Legion Y520-15IKBN              Gaming    15.6
# 1281    Acer                   Aspire ES1-531            Notebook    15.6
# 1168  Lenovo  V110-15ISK (i3-6006U/4GB/1TB/No            Notebook    15.6
# 1231    Dell                    Inspiron 7579  2 in 1 Convertible    15.6
# 1020      HP                      ProBook 640            Notebook    14.0
#
#                                ScreenResolution  \
# 209                           Full HD 1920x1080
# 1281                                   1366x768
# 1168                                   1366x768
# 1231  IPS Panel Full HD / Touchscreen 1920x1080
# 1020                          Full HD 1920x1080
#
#                                        Cpu   Ram     Memory  \
# 209            Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD
# 1281  Intel Celeron Dual Core N3060 1.6GHz   4GB  500GB HDD
# 1168            Intel Core i3 6006U 2.0GHz   4GB    1TB HDD
# 1231            Intel Core i5 7200U 2.5GHz   8GB  256GB SSD
# 1020            Intel Core i5 7200U 2.5GHz   4GB  256GB SSD
#
#                           Gpu       OpSys   Weight
# 209   Nvidia GeForce GTX 1060       No OS    2.4kg
# 1281    Intel HD Graphics 400       Linux    2.4kg
# 1168    Intel HD Graphics 520       No OS    1.9kg
# 1231    Intel HD Graphics 620  Windows 10  2.191kg
# 1020    Intel HD Graphics 620  Windows 10   1.95kg

# %%
X_pred["Ram"]= X_pred["Ram"].str.replace("GB", "").astype(float)

# %%
X_pred["Weight"]= X_pred["Weight"].str.replace("kg", "").astype(float)

# %% [markdown]
#  ## 2. Replicar el procesado para ``test.csv``

# %%
X_pred_1 = X_pred[features].copy()

# %%
X_pred_1
# Out:
#       Inches  Weight   Ram
# 209     15.6   2.400  16.0
# 1281    15.6   2.400   4.0
# 1168    15.6   1.900   4.0
# 1231    15.6   2.191   8.0
# 1020    14.0   1.950   4.0
# ...      ...     ...   ...
# 820     17.3   2.900  16.0
# 948     14.0   1.470   4.0
# 483     15.6   1.780   8.0
# 1017    14.0   1.640   4.0
# 421     13.3   1.270   8.0
#
# [391 rows x 3 columns]

# %%
predictions_submit = model.predict(X_pred_1)
predictions_submit
# Out:
# array([1452.02434921,  473.79530886,  479.84250591,  808.47014856,
#        1070.49066667,  610.29286   ,  678.64304363, 1435.67792381,
#        1671.21732429,  489.3899    , 2272.9651619 , 1687.10714921,
#         500.84583442, 1477.7286    , 1057.98774603,  422.95580828,
